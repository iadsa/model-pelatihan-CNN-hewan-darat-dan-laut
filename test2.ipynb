# %% [markdown]
# Pra Pemrosesan

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Path ke dataset
train_dir = 'D:/ADSA/KULIAH/SEMESTER 4/KECERDASAN BUATAN/Kecerdasan Buatan Klasifikasi Hewan Bagi Anak'

# Pra-pemrosesan data
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2) 

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=20,
    class_mode='categorical',
    subset='training' 
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=20,
    class_mode='categorical',
    subset='validation' 
)
# Out:
# Found 791 images belonging to 3 classes.
# Found 196 images belonging to 3 classes.

# %% [markdown]
# Arsitektur

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# Model CNN
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(len(train_generator.class_indices), activation='softmax')
])

model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Melatih Model CNN

# %%
# Melatih Model CNN
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=30,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size
)
# Out:
# Epoch 1/30
# c:\Users\agusa\AppData\Local\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 132s 3s/step - accuracy: 0.3804 - loss: 1.2281 - val_accuracy: 0.4000 - val_loss: 1.0599
# Epoch 2/30
#  1/39 ━━━━━━━━━━━━━━━━━━━━ 32s 861ms/step - accuracy: 0.5000 - loss: 1.1112
# c:\Users\agusa\AppData\Local\anaconda3\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.5000 - loss: 1.1112 - val_accuracy: 0.3750 - val_loss: 1.0381
# Epoch 3/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 104s 2s/step - accuracy: 0.4272 - loss: 1.0470 - val_accuracy: 0.4278 - val_loss: 1.0676
# Epoch 4/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.4000 - loss: 1.0622 - val_accuracy: 0.3750 - val_loss: 1.0267
# Epoch 5/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.4815 - loss: 1.0056 - val_accuracy: 0.3778 - val_loss: 1.0620
# Epoch 6/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5500 - loss: 0.9764 - val_accuracy: 0.3125 - val_loss: 1.1271
# Epoch 7/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - accuracy: 0.5731 - loss: 0.9446 - val_accuracy: 0.4056 - val_loss: 1.0809
# Epoch 8/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.6500 - loss: 0.8356 - val_accuracy: 0.4375 - val_loss: 1.0934
# Epoch 9/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 104s 3s/step - accuracy: 0.6333 - loss: 0.8827 - val_accuracy: 0.3778 - val_loss: 1.0949
# Epoch 10/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 17s 424ms/step - accuracy: 0.6000 - loss: 0.8944 - val_accuracy: 0.4375 - val_loss: 0.9729
# Epoch 11/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step - accuracy: 0.6470 - loss: 0.8016 - val_accuracy: 0.3944 - val_loss: 1.0839
# Epoch 12/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.8500 - loss: 0.5820 - val_accuracy: 0.2500 - val_loss: 1.2453
# Epoch 13/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 93s 2s/step - accuracy: 0.6634 - loss: 0.7324 - val_accuracy: 0.4222 - val_loss: 1.1361
# Epoch 14/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.6500 - loss: 0.8821 - val_accuracy: 0.5000 - val_loss: 1.0235
# Epoch 15/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 101s 2s/step - accuracy: 0.6911 - loss: 0.7030 - val_accuracy: 0.3833 - val_loss: 1.1215
# Epoch 16/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.6000 - loss: 0.7560 - val_accuracy: 0.4375 - val_loss: 1.0095
# Epoch 17/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.7067 - loss: 0.6733 - val_accuracy: 0.3556 - val_loss: 1.1434
# Epoch 18/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6500 - loss: 0.6901 - val_accuracy: 0.3750 - val_loss: 1.2489
# Epoch 19/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.7505 - loss: 0.6179 - val_accuracy: 0.4111 - val_loss: 1.1609
# Epoch 20/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8000 - loss: 0.4846 - val_accuracy: 0.5000 - val_loss: 1.1857
# Epoch 21/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 42s 957ms/step - accuracy: 0.7917 - loss: 0.5588 - val_accuracy: 0.3667 - val_loss: 1.2049
# Epoch 22/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7000 - loss: 0.5515 - val_accuracy: 0.5625 - val_loss: 1.1950
# Epoch 23/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.7942 - loss: 0.5261 - val_accuracy: 0.3833 - val_loss: 1.1384
# Epoch 24/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8000 - loss: 0.4877 - val_accuracy: 0.2500 - val_loss: 1.2451
# Epoch 25/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.8132 - loss: 0.5036 - val_accuracy: 0.3833 - val_loss: 1.2471
# Epoch 26/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8000 - loss: 0.5887 - val_accuracy: 0.4375 - val_loss: 1.1046
# Epoch 27/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.8400 - loss: 0.4342 - val_accuracy: 0.3833 - val_loss: 1.2955
# Epoch 28/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8000 - loss: 0.5817 - val_accuracy: 0.6875 - val_loss: 0.8526
# Epoch 29/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.8730 - loss: 0.3802 - val_accuracy: 0.4167 - val_loss: 1.2696
# Epoch 30/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8000 - loss: 0.4757 - val_accuracy: 0.4375 - val_loss: 1.2637

# %% [markdown]
# Grafik

# %%
import matplotlib.pyplot as plt

# Menampilkan Grafik Akurasi dan Loss
def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    epochs = range(len(acc))
    
    plt.figure(figsize=(12, 4))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'r', label='Training Accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'r', label='Training Loss')
    plt.plot(epochs, val_loss, 'b', label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    
    plt.show()

plot_history(history)

# %% [markdown]
# Evaluasi Model

# %%
# Evaluasi model
eval_result = model.evaluate(validation_generator)
print(f"\nTest accuracy: {eval_result[1]*100:.2f}%")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 636ms/step - accuracy: 0.3555 - loss: 1.2823
#
# Test accuracy: 40.31%
